# %% [markdown]
# Compute distances for distance KDE

# %%
# setup
import gridtools as gt
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import numpy as np
import pandas as pd
# %matplotlib qt

from plotstyle import PlotStyle

s = PlotStyle()
dataroot = "../preprocessing_output/"
eventstats = pd.read_csv(dataroot + "eventstats.csv")
recs = gt.ListRecordings(dataroot)

# compute distance kde's
all_distances = []
dyad_distances = []
event_distances = []
n_all = 0
n_interact = 0
n_events = 0

for recording in recs.recordings:
    datapath = recs.dataroot + recording + "/"
    grid = gt.GridTracks(datapath, finespec=False)
    events = pd.read_csv(datapath + "events.csv")

    # get all distances
    n_all += len(grid.ids)
    dyad_ids = gt.utils.unique_combinations1d(grid.ids)
    for ids in dyad_ids:
        dyad = gt.Dyad(grid, ids)
        if dyad.overlap is True:
            all_distances.extend(dyad.dpos.tolist())

    # get unique interacting dyad distances
    dyads = []
    uniq1 = list(np.unique(events.id1))
    uniq2 = list(np.unique(events.id2))
    all_ids = np.unique(np.append(uniq1, uniq2))
    n_interact += len(all_ids)

    for idx in events.index:
        dy = sorted([events.id1[idx], events.id2[idx]])
        dyads.append(dy)
    unique_dyads = [list(x) for x in set(tuple(x) for x in dyads)]
    for ids in unique_dyads:
        dyad = gt.Dyad(grid, ids)
        if dyad.overlap is True:
            dyad_distances.extend(dyad.dpos.tolist())

    # get distances during events
    for idx in events.index:
        dyad = gt.Dyad(grid, [int(events.id1[idx]), int(events.id2[idx])])
        start = gt.utils.find_closest(dyad.times, float(events.start[idx]))
        stop = gt.utils.find_closest(dyad.times, float(events.stop[idx]))
        event_distances.extend(dyad.dpos[start:stop].tolist())
        n_events += 1

# convert to numpy arrays
all_distances = np.asarray(all_distances)
dyad_distances = np.asarray(dyad_distances)
event_distances = np.asarray(event_distances)
# Out:
# [ GridTracks.__init__ ] No grid metadata found in directory ../preprocessing_output/2016-04-20-18_49/
# [ GridTracks.__init__ ] No grid metadata found in directory ../preprocessing_output/2016-04-18-19_22/
# [ GridTracks.__init__ ] No grid metadata found in directory ../preprocessing_output/2016-04-16-18_45/
# [ Dyad.__init__ ] Supplied identities do not share a common overlap!
# [ Dyad.__init__ ] Supplied identities do not share a common overlap!
# [ Dyad.__init__ ] Supplied identities do not share a common overlap!
# [ Dyad.__init__ ] Supplied identities do not share a common overlap!
# [ Dyad.__init__ ] Supplied identities do not share a common overlap!
# [ Dyad.__init__ ] Supplied identities do not share a common overlap!
# [ Dyad.__init__ ] Supplied identities do not share a common overlap!
# [ Dyad.__init__ ] Supplied identities do not share a common overlap!
# [ GridTracks.__init__ ] No temperature an light data found in directory ../preprocessing_output/2016-04-09-22_25/.
# [ GridTracks.__init__ ] No grid metadata found in directory ../preprocessing_output/2016-04-09-22_25/
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__ ] Supplied identities do not share a common overlap!
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__ ] Supplied identities do not share a common overlap!
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__ ] Supplied identities do not share a common overlap!
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__ ] Supplied identities do not share a common overlap!
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__ ] Supplied identities do not share a common overlap!
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__ ] Supplied identities do not share a common overlap!
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.

# %%
# make kdes for all
xlims_dpos = [0, 400]
bandwidth = 10

# compute kde
kde_d_all = gt.utils.kde1d(all_distances, bandwidth, xlims_dpos)
kde_d_interact = gt.utils.kde1d(dyad_distances, bandwidth, xlims_dpos)
kde_d_events = gt.utils.kde1d(event_distances, bandwidth, xlims_dpos)

kde_d_all = dict(x=kde_d_all[0], y = kde_d_all[1])
kde_d_interact = dict(x=kde_d_interact[0], y = kde_d_interact[1])
kde_d_events = dict(x=kde_d_events[0], y = kde_d_events[1])

kde_d_all = pd.DataFrame(kde_d_all)
kde_d_interact = pd.DataFrame(kde_d_interact)
kde_d_events = pd.DataFrame(kde_d_events)

kde_d_all.to_csv("../processed_data/kde_d_all.csv")
kde_d_interact.to_csv("../processed_data/kde_d_interact.csv")
kde_d_events.to_csv("../processed_data/kde_d_events.csv")
# Out:
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9979630526210534
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9934363360970784
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9558349107146368

# %% [markdown]
# Export up-modulation during Events for initiators as reactors (data and KDE)

# %%
resting_init = []
resting_react = []
max_init = []
max_react = []
diff_resting_withstatus = []
diff_resting = []

for idx in eventstats.index:
    init_id = float(eventstats.initiator[idx])

    diff_resting.append(abs(eventstats["restingf_id1"][idx] - eventstats["restingf_id2"][idx]))
    if np.isnan(init_id) == False:
        
        if int(init_id) == eventstats.id1[idx]:
            resting_init.append(float(eventstats.restingf_id1[idx]))
            max_init.append(float(eventstats.maxeventf_id1[idx]))
            resting_react.append(float(eventstats.restingf_id2[idx]))
            max_react.append(float(eventstats.maxeventf_id2[idx]))
        
        elif int(init_id) == eventstats.id2[idx]:
            resting_init.append(float(eventstats.restingf_id2[idx]))
            max_init.append(float(eventstats.maxeventf_id2[idx]))
            resting_react.append(float(eventstats.restingf_id1[idx]))
            max_react.append(float(eventstats.maxeventf_id1[idx]))
        
        diff_resting_withstatus.append(abs(eventstats["restingf_id1"][idx] - eventstats["restingf_id2"][idx]))

resting_init = np.asarray(resting_init)
resting_react = np.asarray(resting_react)
max_init = np.asarray(max_init)
max_react = np.asarray(max_react)

resting_initreact_diff = resting_init - resting_react
kde_f_restinginitreact_diff = gt.utils.kde1d(resting_initreact_diff, 2)

init_amp = max_init - resting_init
react_amp = max_react - resting_react

xlims = [0, 50]
kde_react_amp = gt.utils.kde1d(react_amp, 1, xlims)
kde_init_amp = gt.utils.kde1d(init_amp, 1, xlims)

event_f_increase = dict(init=init_amp, react=react_amp)
event_f_increase = pd.DataFrame(event_f_increase)
event_f_increase.to_csv("../processed_data/event_f_increase.csv")

kde_react_increase = dict(x=kde_react_amp[0], y=kde_react_amp[1])
kde_react_increase = pd.DataFrame(kde_react_increase)
kde_react_increase.to_csv("../processed_data/kde_react_increase.csv")

kde_init_increase = dict(x=kde_init_amp[0], y = kde_init_amp[1])
kde_init_increase = pd.DataFrame(kde_init_increase)
kde_init_increase.to_csv("../processed_data/kde_init_increase.csv")
# Out:
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9328044712312922
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9999999861049931
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9999999977347609

# %% [markdown]
# Get delta f of dyads before and during events

# %%
diff_resting = abs(eventstats["restingf_id1"] - eventstats["restingf_id2"])

diff_f_before_vs_during_event = dict(before=diff_resting, during=eventstats["diff_medianevent"])
diff_f_before_vs_during_event = pd.DataFrame(diff_f_before_vs_during_event)
diff_f_before_vs_during_event.to_csv("../processed_data/diff_f_before_vs_during_event.csv")

# %% [markdown]
# Extract resting initiator ID - resting reactor ID

# %%
resting_init = []
resting_react = []
max_init = []
max_react = []
diff_resting_withstatus = []
diff_resting = []

for idx in eventstats.index:
    init_id = float(eventstats.initiator[idx])

    diff_resting.append(abs(eventstats["restingf_id1"][idx] - eventstats["restingf_id2"][idx]))
    if np.isnan(init_id) == False:
        
        if int(init_id) == eventstats.id1[idx]:
            resting_init.append(float(eventstats.restingf_id1[idx]))
            max_init.append(float(eventstats.maxeventf_id1[idx]))
            resting_react.append(float(eventstats.restingf_id2[idx]))
            max_react.append(float(eventstats.maxeventf_id2[idx]))
        
        elif int(init_id) == eventstats.id2[idx]:
            resting_init.append(float(eventstats.restingf_id2[idx]))
            max_init.append(float(eventstats.maxeventf_id2[idx]))
            resting_react.append(float(eventstats.restingf_id1[idx]))
            max_react.append(float(eventstats.maxeventf_id1[idx]))
        
        diff_resting_withstatus.append(abs(eventstats["restingf_id1"][idx] - eventstats["restingf_id2"][idx]))

resting_init = np.asarray(resting_init)
resting_react = np.asarray(resting_react)
max_init = np.asarray(max_init)
max_react = np.asarray(max_react)

resting_initreact_diff = resting_init - resting_react
kde_f_restinginitreact_diff = gt.utils.kde1d(resting_initreact_diff, 2)

resting_initreact_diff = dict(diff_resting = resting_initreact_diff)
resting_initreact_diff = pd.DataFrame(resting_initreact_diff)
resting_initreact_diff.to_csv("../processed_data/diff_f_init_react.csv")

kde_f_restinginitreact_diff = dict(x=kde_f_restinginitreact_diff[0], y=kde_f_restinginitreact_diff[1])
kde_f_restinginitreact_diff = pd.DataFrame(kde_f_restinginitreact_diff)
kde_f_restinginitreact_diff.to_csv("../processed_data/kde_f_restinginitreact_diff.csv")
# Out:
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9328044712312922

# %% [markdown]
# Extract physical interaction events for initiators, reactors and total and appropriate time axis.

# %%
all_veloc = []
dyad_veloc = []
event_veloc = []
event_interactions_init = []
event_interactions_react = []
event_interactions = []
event_interactions_ts = []
event_durations = []

for recording in recs.recordings:
    datapath = recs.dataroot + recording + "/"
    grid = gt.GridTracks(datapath, finespec=False)
    events = pd.read_csv(datapath + "events.csv")

    # get all distances
    for track_id in grid.ids:
        t = grid.times[grid.idx_v[grid.ident_v == track_id]]
        x = grid.xpos_smth[grid.ident_v == track_id]
        y = grid.ypos_smth[grid.ident_v == track_id]
        v = gt.utils.velocity2d(t, x, y)
        all_veloc.extend(v.tolist())

    # get unique interacting dyad distances
    dyads = []
    uniq1 = list(np.unique(events.id1))
    uniq2 = list(np.unique(events.id2))
    all_ids = np.unique(np.append(uniq1, uniq2))
    for track_id in all_ids:
        t = grid.times[grid.idx_v[grid.ident_v == track_id]]
        x = grid.xpos_smth[grid.ident_v == track_id]
        y = grid.ypos_smth[grid.ident_v == track_id]
        v = gt.utils.velocity2d(t, x, y)
        dyad_veloc.extend(v.tolist())

    # get data during events
    for idx in events.index:

        # extract all positions for kde
        dyad = gt.Dyad(grid, [int(events.id1[idx]), int(events.id2[idx])])
        start = gt.utils.find_closest(dyad.times, float(events.start[idx]))
        stop = gt.utils.find_closest(dyad.times, float(events.stop[idx]))

        t = dyad.times[start:stop]
        x1 = dyad.xpos_smth_id1[start:stop]
        x2 = dyad.xpos_smth_id2[start:stop]
        y1 = dyad.xpos_smth_id1[start:stop]
        y2 = dyad.xpos_smth_id2[start:stop]

        v1 = gt.utils.velocity2d(t, x1, y1)
        v2 = gt.utils.velocity2d(t, x2, y2)

        v = np.append(v1, v2)
        event_veloc.extend(v.tolist())

        # get event edurations
        dur = dyad.times[stop]-dyad.times[start]

        # extract social events for event triggered interactions

        # get approx 5 minutes before event start and 10 minutes after event start
        start2 = start - 1000
        stop2 = start + 2000

        t_rasterplot = dyad.times[start2:stop2] - dyad.times[start]
        
        peakprom = 1
        maxd = 25

        peaks1, peaks2 = gt.utils.find_interactions(dyad, start2, stop2, maxd=maxd, peakprom=peakprom)
        peaks = np.append(peaks1, peaks2)

        # detect interactions for intiators and reactors
        if events.init[idx] == events.id1[idx]:
            peaks_init, peaks_react = gt.utils.find_interactions(dyad, start2, stop2, maxd=maxd, peakprom=peakprom)
            event_durations.append(dur)
        elif events.init[idx] == events.id2[idx]:
            peaks_react, peaks_init = gt.utils.find_interactions(dyad, start2, stop2, maxd=maxd, peakprom=peakprom)
            event_durations.append(dur)
        else:
            continue

        # append to list    
        event_interactions_init.append(peaks_init)
        event_interactions_react.append(peaks_react)
        event_interactions.append(peaks)


# convert to numpy arrays
t_rasterplot = np.asarray(t_rasterplot)

# sort events by syncrhonized duration in reverse order, then sort duration
event_interactions_init = [x for _, x in sorted(zip(event_durations, event_interactions_init), key=lambda pair: pair[0], reverse=True)]
event_interactions_react = [x for _, x in sorted(zip(event_durations, event_interactions_react), key=lambda pair: pair[0], reverse=True)]
event_interactions = [x for _, x in sorted(zip(event_durations, event_interactions), key=lambda pair: pair[0], reverse=True)]

# sort event durations as well
event_durations.sort(reverse=True)
# Out:
# [ GridTracks.__init__ ] No grid metadata found in directory ../preprocessing_output/2016-04-20-18_49/
# [ GridTracks.__init__ ] No grid metadata found in directory ../preprocessing_output/2016-04-18-19_22/
# [ GridTracks.__init__ ] No grid metadata found in directory ../preprocessing_output/2016-04-16-18_45/
# [ GridTracks.__init__ ] No temperature an light data found in directory ../preprocessing_output/2016-04-09-22_25/.
# [ GridTracks.__init__ ] No grid metadata found in directory ../preprocessing_output/2016-04-09-22_25/
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.

# %% [markdown]
# Make kde for interaction events rasterplot, i.e. event onset triggered interactions and transform peak indices to timestamps

# %%
# make kde for interaction events rasterplot, i.e. event onset triggered interactions
bandwidth = 10
#event_interactions_flat = np.concatenate(event_interactions)

# flatten data
init_flattened = np.concatenate(event_interactions_init)
react_flattened = np.concatenate(event_interactions_react)
all_flattened = np.concatenate(event_interactions)

# make flattened timestamps
init_ts = t_rasterplot[init_flattened]
react_ts = t_rasterplot[react_flattened]
all_ts = t_rasterplot[all_flattened]

# calculate separate kdes:
init_raster_kde = gt.utils.kde1d(init_ts, bandwidth, [np.min(t_rasterplot), np.max(t_rasterplot)])
react_raster_kde = gt.utils.kde1d(react_ts, bandwidth, [np.min(t_rasterplot), np.max(t_rasterplot)])
all_raster_kde = gt.utils.kde1d(all_ts, bandwidth, [np.min(t_rasterplot), np.max(t_rasterplot)])

# save kdes to file
init_raster_kde = dict(x=init_raster_kde[0], y=init_raster_kde[1])
react_raster_kde = dict(x=react_raster_kde[0], y=react_raster_kde[1])
all_raster_kde = dict(x=all_raster_kde[0], y=all_raster_kde[1])

init_raster_kde = pd.DataFrame(init_raster_kde)
react_raster_kde = pd.DataFrame(react_raster_kde)
all_raster_kde = pd.DataFrame(all_raster_kde)

init_raster_kde.to_csv('../processed_data/kde_raster_init.csv')
react_raster_kde.to_csv('../processed_data/kde_raster_react.csv')
all_raster_kde.to_csv('../processed_data/kde_raster_all.csv')

# make timestamp matrices
raster_ts_init = []
raster_ts_react = []
raster_ts_all = []
for init, react, interact in zip(event_interactions_init, event_interactions_react, event_interactions):
    rti = t_rasterplot[init]
    rtr = t_rasterplot[react]
    rta = t_rasterplot[interact]
    raster_ts_init.append(rti)
    raster_ts_react.append(rtr)
    raster_ts_all.append(rta)

# save timestamp matrices
np.save("../processed_data/raster_ts_init.npy", raster_ts_init, allow_pickle=True)
np.save("../processed_data/raster_ts_react.npy", raster_ts_react, allow_pickle=True)
np.save("../processed_data/raster_ts_all.npy", raster_ts_all, allow_pickle=True)
# Out:
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899438573306721
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9941783933566748
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9920498030548321
# /home/weygoldt/Data/uni/efish/env/lib/python3.10/site-packages/numpy/lib/npyio.py:518: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = np.asanyarray(arr)

# %% [markdown]
# Jigsaw and resampling

# %%
# extract event df
bandwidth = 10

nsamples = len(all_ts) # all timestamps, i.e. all interaction events
nresamples = 10000

all_ts = sorted(all_ts)
# plt.eventplot(all_ts)

diffs = np.diff(all_ts, prepend = all_ts[0])

print(f'timestamp length: {len(all_ts)}')
print(f'diffs length: {len(diffs)}')

print(f'timestamps: {all_ts[0:10]}')
print(f'diffs: {diffs[0:10]}')

kdes = [] # collect kdes here

# resample
for i in range(nresamples):

    # shuffle randomly
    np.random.shuffle(diffs)

    # make shuffled to timestamps starting with first time point
    randevents = np.concatenate(([t_rasterplot[0]], diffs)).cumsum()

    # compute kde
    randkde = gt.utils.kde1d(randevents, bandwidth)

    # stash kde
    kdes.append(randkde[1])

# compute median
kdes = np.asarray(kdes)
plt.plot(all_raster_kde['x'], all_raster_kde['y'], color = 'red', lw = 3)

baseline_medians = np.median(kdes, axis = 0)
baseline_q5s = np.quantile(kdes, 0.05, axis=0)
baseline_q95s = np.quantile(kdes, 0.95, axis=0)
# Out:
# timestamp length: 561
# diffs length: 561
# timestamps: [-326.6954499999956, -325.3846499999963, -319.15889999999854, -316.537849999997, -316.537849999997, -315.5547499999957, -315.2270499999977, -314.89934999999605, -310.9669499999982, -310.9669499999982]
# diffs: [0.      1.3108  6.22575 2.62105 0.      0.9831  0.3277  0.3277  3.9324
#  0.     ]
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9927655112892122
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9909896661665689
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907747870612267
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.991061532355153
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9853792032753108
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9870310574040204
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899685993661402
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9874274580202913
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9877563906138828
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9867310001774947
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9878015315648331
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901315596847147
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893571306950683
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9921565656190199
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9843246229407641
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9864182414160363
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9865982283812595
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.991406215269957
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9942824400172825
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907489495718853
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9938756298717792
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9938094303031608
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9859530267459933
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895396880316658
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9835645247271175
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9846275265289086
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904656575676262
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9888630449395587
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914101573121528
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9857086527118152
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900280146626212
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897425547848332
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902226514957668
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897636785282835
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9867484601382542
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9944412201589437
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.987154521714334
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9919838204951372
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.985374570699156
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9945370879890576
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9863618328976502
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9839942750373816
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9930329710724846
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9892786818781896
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896926041845187
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9891650976288343
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9878174584129393
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9841601177094619
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.987093462323025
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9926835260906521
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9942819831899682
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.99070883070678
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9875094052236842
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.986435742529383
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9927823461825593
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9884854067221821
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9834000135167011
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9845175297929124
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.988077253978741
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910470574704628
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907513844501881
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910717986792033
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903219014788324
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911584326770615
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9854488955587265
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910873265775164
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910517237033972
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910024806581275
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9885220238991155
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9877662257793074
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.986735520652667
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9851856732222085
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9891044371390048
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902419670151729
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9889274488043746
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894525948620598
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9855424556226802
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9840714176841019
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9886767547297305
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9884102958036416
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907160498139879
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.983523167187375
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9874386930090369
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.99156251995412
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895796006090631
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9882796907107921
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9884774558715032
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911689976013961
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9942118110092644
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9889519554462172
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9939927473721277
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9923615957430076
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9865845027125638
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9875580622881764
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9922232069331279
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897797337413871
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9892273893497967
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9918066587682978
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9879134460575658
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9878742385649222
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9930143883202251
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9860571605972813
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910595789426054
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893374393928376
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9940494279889058
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9862180496490675
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9879634032148004
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897715018213353
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9872495305325847
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900234175173432
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.987478673405071
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9877233654160805
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9846881243263599
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9855866522326483
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9874362120921447
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9824972827299685
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9853357972607563
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9853027172959163
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9917235014534072
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900892971430597
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.98790213403138
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9887116585755955
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893569174342621
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9871032211552639
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901191386991703
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9938924514252551
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896122728266182
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902622285299219
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896151413622043
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9880639006176791
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9882688460257427
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9915725419476948
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907445577507522
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9891834623677804
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9876690463384112
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906995216270151
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9876046575903263
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894080543913351
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9931329333454562
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9879561122209068
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914751812911816
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.984293567993925
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9850533165112373
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.99115673447898
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9885317567340861
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9884373084744147
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9866848488376341
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.985156294056325
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9892238615669234
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9872567376448168
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893298659768159
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9849062221862173
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9882606855531613
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9949580463408366
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9855851214895721
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9937748973004354
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906698573202293
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903628688081434
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.984226173988982
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9878610175223779
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9868580885272811
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9917775969910027
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9869847905792462
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914176262188541
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.984446693446063
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9881434720694708
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9864189546062989
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912452631350336
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9880894936212419
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.987515154548587
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9855113053080248
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9857980045404324
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911444154623816
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899025090128929
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9942833335546806
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9873811007684051
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9925916864978102
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.984886188057962
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908234398066749
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.99177651114123
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9876335355078157
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9925183827830466
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9909164150586862
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9930575536704191
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9877200086613135
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.992179391184608
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9850588808971601
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9887702604268505
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9876645452268691
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9920975263907681
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894379093179603
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894679408452935
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910027098513305
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9887264088634667
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9823093062521646
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9927754025649963
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907839793511652
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908024499545367
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897495713727265
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9872411735158451
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9884920954693706
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9929322718535883
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9877803977752685
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903810117944605
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9940928743800916
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907041793323661
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9850077568782523
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895328129466352
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904801882040137
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906648309623445
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9871939829895017
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9934055959153469
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898099918146244
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9926185684851154
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903211362279256
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907305246564662
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9820057770358211
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904594446568851
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9927819749965059
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901611622397883
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9877227662808532
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9887096978282366
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9889938764829318
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895156495810862
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989018567917232
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9945902320590164
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910024896335533
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9876403931559105
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9862811633140274
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989203068766809
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914879261468152
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9884527620541097
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9925703885425847
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9932057691625769
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9866224399703729
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9888139698754426
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9923009762657884
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9917605855887806
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9917154847282335
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9930632068766758
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9932644058844016
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.991033247553379
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9935214262136014
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900371551516112
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.993439788549968
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9874511139103593
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9887230184634763
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9871555559576846
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9862528785876528
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9833237444967632
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908070350274396
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989020866446212
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913820336792096
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9867867156681249
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9877235915502333
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9892910584083218
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9934133622807708
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9943217249329923
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9874088933873644
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9858446067128951
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9926297793483354
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897745228601106
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9878242101286663
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.988007922989963
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906729078124508
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898632255661647
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9870995522203052
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904150120630864
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9855209430915525
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913968320258212
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990954051946709
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9869080191657585
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990295803798696
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9920794932661783
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.99016280971744
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9932951858449175
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.984463707061271
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899690029180435
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.995510613915653
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9887613592401963
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9860472554941839
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9915682482681901
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9865394798239264
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9884173351342895
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9880202561438437
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897705938829457
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9930613975966611
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9931552851341601
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9840753573734304
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.98802948381168
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9886777212177817
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9891016015662993
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914267367273669
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9862722213995639
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9919406563224191
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9874793693638847
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905293508570155
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9860697913677949
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9888965540407681
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9933287314754992
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898599340471503
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908319383697622
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9877047129607333
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9885516471532787
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895399131908772
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9884704433346234
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901564977441275
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9952992096142488
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9854546960355515
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.988554257657885
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9867724146479058
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9867946380120308
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.991581452643982
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9850332546230384
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9931276959885167
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914584150578835
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.988245282068046
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9951542096237421
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.991701885316024
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9872398452251833
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9884955589364904
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9844850122536948
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9932292669178476
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9922682176492658
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9887548835805647
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9892949386643928
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9889812944688192
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9919601314363831
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9886523349906028
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913478812029584
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910392781691817
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908927559450956
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9939624209078135
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.985625633268868
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.986395785232437
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9828724533331084
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9951427211709736
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.987696691957349
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9920124648465761
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893320883256465
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905989767297327
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913794554678277
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912321304985265
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990895049138184
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9853141742517495
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903966568421065
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901249071590146
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902810280578693
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908448370819636
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908498996960172
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9886164426602887
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899275125047279
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910276444423523
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9799577137696082
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9875581676662062
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9931225170517197
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906676101761828
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902895202342957
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9892977587282641
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905679497595168
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9919343844313704
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9850458513176725
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9890941205807637
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.987435704167583
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.985853455177457
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903177813741888
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9917891710379665
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9888784057887576
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9879676574093854
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9881382648982838
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9943868357331118
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9861739912255705
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905970712399663
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9886327901595608
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9920125241890961
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989673250235604
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9882812322001404
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896420516224695
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9891330738602676
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9843889476114438
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9852082477441023
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990750629403313
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9915269768553626
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9883281155953845
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9916976506004158
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897830524737442
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9930109200806531
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9889449495708409
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9880163595613667
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9930080143913875
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897269577217446
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902302957907664
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9915060870300654
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904755497120227
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9953400890241477
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9928031751626123
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9860333312437358
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9930134248109556
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.99126402614193
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899823368839791
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9922294738025468
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9942649093550733
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9937434385702495
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9882690541313103
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9841532346613001
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895286571038058
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9921931528872021
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905005150724979
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898493272303488
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893766892810038
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9890970811142212
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9878742288005127
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9946307427939439
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9883133800177952
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9874897501154201
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9863629989996937
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9858814167243142
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990729534600627
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.991385935770653
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9927490196103859
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9855602263690092
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905313534989783
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9851472700168284
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9938281629104082
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.991097673564674
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9869236183270251
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9875507425856369
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9878362966160419
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901783860125547
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9883304648316404
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9943817465819371
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900569894411058
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9889601776535181
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9874783252076469
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911226697129284
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.992203271684299
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911000979751328
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9882232323091462
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893522442413909
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9825783822371517
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9855275375255468
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9834133281645345
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9871418543888733
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9874394797906201
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9880291604994259
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9892027814158515
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9883333707931486
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911092959957103
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9871456264322513
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904991371614393
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.994766513753143
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9925656747570615
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9846823441453127
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9890832786503463
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9871563444279002
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895571219461036
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9855217554561465
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9851356387912462
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9880282390083079
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9940162733260212
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9882746820550423
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.98415167792318
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900631864046705
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.992458119171982
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896657810409942
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.991392059041774
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.992922036807638
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9878776094916865
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910232075005225
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9873997833385921
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897039437371432
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912351110142267
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9929067340464635
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9866348535930551
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9858014519594536
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9871108230124886
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893489082165976
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898559908400116
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990608274673037
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895726510203926
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9848294875489392
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9840147721747673
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897721742254996
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9930758136717166
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9936095065179955
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9860602630032311
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9885147049382097
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9847914598832572
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.995453398982379
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9870501722689938
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.986003155315436
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9862721714168677
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9909356657011297
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9884084290513431
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9929086806967148
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9879273327719916
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894175041035072
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900825702725999
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904099788862003
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9928941086191378
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9931157838790303
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9885555834360169
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898542250425599
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.992704528351205
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913001903734173
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.993445532915047
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9872700694162123
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9932445331303349
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9877424509891264
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9915665833157694
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9915557184936159
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.99075740232986
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907902079682936
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9844335891488564
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912812845814623
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9928109778266013
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9887309423499444
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9850918717539187
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897098207564435
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.988903773326264
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9882086758587769
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9845458240040212
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902191115404637
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.988644673298422
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9875342934217857
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9929830770172339
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9890702971511337
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914075483310135
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.991235072697582
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9871000966107453
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.992750080347347
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9844231684691139
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9922589375400066
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9930079922304688
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898459344137343
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9851900996500813
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9843609972567424
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9867837977537031
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.986748407491145
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907204642229863
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9875103087801274
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9919759461106155
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9882325981700837
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9932910089486457
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9918654910294333
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9870665994828351
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.992238616441306
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894642481438387
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9873020917710961
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9938907650016318
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.988742740618667
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.99029551907838
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9920268422665185
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9923933011251915
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9888227419909372
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901054425816727
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9915521739431556
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9850198297723483
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899450424892158
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9892734317278656
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989494875754112
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9849483438303778
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9850860767042695
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9924664558871554
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895785013828373
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9807523274857874
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9880653448586423
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9883817568492179
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896863100437582
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9879800488510222
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9880278864681229
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.987858076932107
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9873193603762604
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9855683985039176
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895603822771211
# ...
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9857659467279691
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9863094841987645
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.994377655472455
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.986337494009738
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903290869480149
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900598984126856
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910737858783034
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9883121478607506
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9817208963615974
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9847061631161818
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9916496421806841
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9853629062818319
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9886991111948307
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9860827167552286
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895869526386452
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.99120469586444
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9887273854609346
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9937089746936849
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9909503690967387
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9856585742071877
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9917720906268197
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.993838297727158
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9920846832065471
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905463405785804
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9878204076535267
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9874490633234352
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9869066366657983
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900481681590734
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990952969003688
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9916520631909831
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901457632451811
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9883025418567588
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9879377946699088
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9866717997006209
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9886340849150383
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911164356165922
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9932401218649856
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9883254448989884
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9882882913298877
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9850182711809099
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913962239325573
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9932711754014054
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9873383513417898
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9946355150508525
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9854544999369865
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.984685124707459
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9862974894761902
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903228524020716
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9887799723412283
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9892753272548253
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9888209477253633
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901807374017766
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9934317759771003
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9865563590148658
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990941435600052
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902042194024964
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9926963993308444
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906513931636352
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895800382538461
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9883129700667804
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9876706657228593
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896504955783456
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9918664971580577
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9873246372266286
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9859241120220152
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.995979802047827
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9835874210234673
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9909499024417484
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.991542741571947
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9869390510810614
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903150237658405
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9872690931034465
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9878135595819423
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9918335994100994
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9946630922050914
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9853126975777169
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904191730800295
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9887602616960258
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9879239799237813
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901958034677995
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9873294236638255
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.994999013160588
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989377249423703
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9874682876666498
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9918406049811438
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9925809763506588
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9844598372698379
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.993972258815482
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9881989405708639
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9876139760764031
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9866308566324112
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9891156389309702
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895949977641709
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9892230025208218
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.987329186137023
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9888674807766757
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9858638068032979
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9864100724838722
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.995502773833
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9891857984681053
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9918353825888009
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912100577366395
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9881728905902922
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906546358027521
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897331718625713
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9952518235501063
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9880905405305165
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9909613199639838
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9865761840508552
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903800821855973
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9891899316141819
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9882104697121997
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9874079108557531
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9917345909123012
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906005877861079
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906972910399164
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9878132950306011
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9858271178143594
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9857219222619711
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9892952912555859
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9919178008356812
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9936765197343238
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9921580801767956
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9890041478471248
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9927730939005396
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9859710006577067
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.986120763659919
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910687768885034
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9915173384610665
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897302687486201
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9874632305035096
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.986617232856595
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906870600182809
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9920318510447725
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9890968456821596
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9882472740021372
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9918592950832492
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9858705507147852
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9892826372164375
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901254508356268
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893103855075405
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9866004155953698
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9944192924131046
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9919069746642708
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911843310633053
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908569208352456
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913040771025771
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9856859824356754
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9883735435976826
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9891755813910428
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9889565818467517
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9881878604881735
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.99022157354171
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9923920968102666
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9871297833187271
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9866417044442056
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.98942902139424
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9882650816129595
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989778249381889
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895992270918141
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913850591586295
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9849280434799379
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913409593106973
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9882037732800606
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9858277936109836
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9856240296270449
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9822456303097453
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9861861170644347
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9942099194199898
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914934622930637
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9936447780284869
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9865532594931183
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9879633410839999
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9888285996610092
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9927727772299417
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9876353337573727
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9870724914212841
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9885182518994402
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9890963965916533
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903275970064
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9873329631050259
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9866615259994119
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903826867011758
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.988586530876792
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9892846167466677
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9889607373820809
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9868479909450324
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9918683339309422
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9931902798135418
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9870845591453206
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9881702697773929
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9842115336959596
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9865135449702785

# %% [markdown]
# Jackknife

# %%
bandwidth = 10

nsamples = len(all_ts) # all timestamps, i.e. all interaction events
nresamples = 10000

all_ts = sorted(all_ts)
# plt.eventplot(all_ts)

kdes = []
subsetsize = int(0.9 * len(all_ts))

# resample
for i in range(nresamples):

    # compute kde
    randkde = gt.utils.kde1d(np.random.choice(all_ts, subsetsize, replace = False), bandwidth)

    # stash kde
    kdes.append(randkde[1])

estimated_medians = np.median(kdes, axis = 0)
estimated_q5s = np.quantile(kdes, 0.05, axis=0)
estimated_q95s = np.quantile(kdes, 0.95, axis=0)
# Out:
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902127690531585
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901891334463572
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893626853578636
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893623592381293
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9909109194844081
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901149784155341
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9909476013387513
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907907987303732
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898591089956471
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911794454632765
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905600720583276
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898308272562408
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9917243630735315
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904289121084072
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893787284448969
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905426758261522
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897728467272663
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901721007566919
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898254902490227
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893632411407133
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896710034797902
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896000711430738
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989971249527732
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989362308396371
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899144485154507
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905576660426784
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9915948633661396
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905687105997611
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897288683511745
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901477062873798
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899275119735531
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989905860937897
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895452443118595
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907795187637923
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894941104838143
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898203105590432
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9919101801235296
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900438544569947
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9915424830195722
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903244936641462
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900833742983965
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898689734709784
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899103132821264
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903293395389327
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901142538381377
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894200366422767
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.991425908298572
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895311279767736
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905327445462156
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895415497496878
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.991885013742167
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903089709684423
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905784342934023
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914075126886644
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903959362527706
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903541380517932
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9915199945350583
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895024341902041
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896952518663718
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914214689663022
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901698010437927
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893764914368492
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910088510474383
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902257328310144
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904306657501849
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912465164183092
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893779051330454
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904542738716144
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9917286149839009
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898102143114027
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902662008497329
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894849579027141
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906778360799269
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905923992284767
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904688524363283
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900653395612833
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906457547668286
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900197835123185
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905247500555593
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895724033862195
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9916643914812475
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908827785489625
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9909379269935541
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908979185212896
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902322455948377
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.991640172235142
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898399860990336
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904304764441825
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896537612932338
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9923867693457904
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990776252623559
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899477006362717
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893689621309185
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911494355990614
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899447072371544
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899519108670987
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990927915898656
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900249408048147
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896412808882956
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893623105502056
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9919337499751433
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897670388855513
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911154849743604
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893623084121232
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910353764786712
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9915158044699917
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9909603935616782
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9909465643399754
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908815247660854
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908829625867678
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893779312984273
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908978887965365
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.99081642057887
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897731298872495
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893676913665063
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893624799171636
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905077914952601
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905211797460116
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899750153551523
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990773802521972
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901721333153675
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906086065634738
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989735922790401
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9916509401892805
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894289245688734
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900587492535778
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893623083966184
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897870242394537
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910254878885527
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897168343589219
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896133259204924
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894854553230124
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895887605909348
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895310632541188
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894783049536855
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899220460864191
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990078613405706
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9916067053563468
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903768612342715
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9921113240885568
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9921897267978796
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897916337955643
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901891567220908
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9909477901556879
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894582361357158
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899145153917209
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895023392156193
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9878139776500967
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895414765940465
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9918113100932311
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902768160334101
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893623879424436
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893734118109053
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896009431313354
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989650287579652
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895181729990606
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904315742288401
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893623553555317
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906769078930261
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905090379344652
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902817657896918
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896559582026321
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989362314078793
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910707717437235
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9917023558812372
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.991448837136025
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907511042456039
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897429895703795
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907511308627401
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894791606011889
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893863525059564
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898887584877074
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905045717579628
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9922498660035171
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906735181313456
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893691347154078
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910052922200643
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989371237799308
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903950285798294
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899425573128515
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912922823563738
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907056474286878
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901893654577859
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898540714897849
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902425740994525
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.991457580463751
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900045802575063
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895503451127097
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897155871353411
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901454429964478
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893623244463063
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905815446089297
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896396840169347
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898502590502549
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903643538745127
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898112481560399
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990810525565861
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903285229689901
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989935978006129
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898790010247824
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903484696379419
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899911991290392
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910526764000918
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906387440030188
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893853900347716
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902219169406407
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989387213716121
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903539606891019
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893628171401556
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902094116561789
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904981801282983
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9917899933297231
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901519225690889
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989367614509373
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901605835462837
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903259919753294
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893679003839164
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905287555290696
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.99046431930315
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905635686397912
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899815558365751
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903832259401739
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900486249946343
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898689756249928
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989658233167196
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901608561507442
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911984752015767
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907839688890887
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896711377476419
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905608858308057
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896952891773992
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893690306667269
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902327191993311
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9909111258376786
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893778286507492
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893668661662742
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894793984032605
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899273318312599
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907219838175845
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990956842054149
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904260512844557
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904253626412471
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898649557311967
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9916071229798106
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895527448027231
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912512853514416
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893779393672755
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913340037817933
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904841576470134
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902256681084105
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904086016989138
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910671426453221
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910218150849865
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898592922422458
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907036560393656
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989362450225812
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9875452120715731
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899819696941111
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899538197008365
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900938034135522
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898798649522683
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905398119241378
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989985961034903
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895455300310219
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900055962237713
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901477853249463
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903089149582694
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911694798167354
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905466798433038
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989541664734424
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898016167054258
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893690793701795
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990160807839196
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910685044738041
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894961441978114
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910210099004976
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904267062191395
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905420228075859
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990343734150706
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912412862672715
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904454173877402
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893623752728276
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907260118004819
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894200519309342
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907647480408809
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899331358099323
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905689234229349
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895413809623856
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897010261392478
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902175847029939
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914575528439225
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908195572439233
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903513259192563
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9919041769203649
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906374757902483
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905491605837436
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903244057857983
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894949554137809
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904644680770058
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.98967200973609
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9919849382685594
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896560636442882
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906174425381521
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901749471289287
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899895763487032
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896712165878464
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906789293327364
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990035956594908
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901751338846203
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900975378183315
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907820435583106
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990494829936047
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905607927254707
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901575624533715
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989392368091239
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990605896315925
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910488601838066
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902278258267061
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904660905496521
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.991594516843121
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990868930164852
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894200078869974
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908705220277988
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913957423698289
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893867290788554
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895653938722957
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901348630115474
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914112006794802
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.987593115194185
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912940005499647
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900612092283714
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896800384994334
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9909106343634777
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895268171110246
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9919337568844453
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910342035159562
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895403290825574
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906916701393912
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904120591110467
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989376544465264
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910892037435307
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898064073716804
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906914363890051
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897498628080414
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898078818663967
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912607319128133
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9918051095461438
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902069453856102
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899099398513694
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990151290427884
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895483199569006
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893952275153564
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901452695985743
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9909162072647377
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895399617322818
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896475140468918
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894246484238614
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911665431295127
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893778284626255
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896652454689858
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896952034820055
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907503116656412
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897728441657294
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914839160469887
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893693612421014
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904543317258867
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912876054444215
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894784755882484
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9918990155171645
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911877918377126
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905285416439642
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896501693984687
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903286940144491
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912326339237011
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893624814755579
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897820259039238
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898782276923958
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896652324832178
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904151663431418
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989919821520476
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902517662633642
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9918625167439539
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913099789087068
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903182770286092
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910131022196613
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.991362023318886
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904256280173307
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893778284626265
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893625461982124
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901453026093041
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896501311161039
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894924855494798
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911326019526927
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905090833760666
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896241185894095
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990341712891871
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903633988104945
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893863268834089
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893626450085868
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898268935652479
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902307616881927
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903231069739364
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905301136854856
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893831427424578
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894783715034989
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905414552357515
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914485873021552
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904371201617782
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901151744099095
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895416645632482
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897393827553718
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902797136944018
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902177300495083
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895416701260129
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905852637104005
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990460499121837
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894851311857751
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893720674112353
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901743138467268
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9919319014615271
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899178012461614
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910702401123689
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899199056778605
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894103419469659
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907653774086829
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913513464830963
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896421830084302
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906362013719787
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913424433187772
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9923379747750526
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9879855732029215
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894917673220682
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903529961861992
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895414554947397
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914528027336555
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912396210724741
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908283790358965
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896067902105591
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903753855700422
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9915938137800212
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900050416187667
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896412348269027
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904601153820837
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899558883202271
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9892160136080099
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989531146180511
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990341696554847
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9915357438702124
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894783046628626
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904629982653084
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9919668507978012
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893623907649989
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910152719783405
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900317041777276
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907487749170161
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913207752117698
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902011600790909
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908103026808434
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9925135741223954
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989843008045628
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899125630583325
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893623084121234
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9886018385777914
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990200342987493
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912364592708575
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904251191563793
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903402653703248
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897341940434786
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899146215944506
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896502804001854
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913825699681751
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990943527387653
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900493474680224
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898112299365504
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911510977277898
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896750874907344
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9916476031578091
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895879600057697
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893823433519255
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9920305034743253
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912039407603322
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900518469156437
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913299820351058
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9909077172581627
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897728465616119
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896413849212846
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990484198953181
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910135906885071
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910636557978308
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910396719698966
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989728855441997
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903609665104077
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906626467005748
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905998498194609
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910614454423459
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9916302618560893
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908697730246867
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9909580268315858
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899815155426543
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911313440738112
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906491910241699
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989974867090835
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902488319406786
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896411922001763
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900205683112988
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900843734733045
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899149563885332
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903171569001459
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906734477978167
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897400860675478
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907923401978567
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901483787970744
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989772846562037
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907966076676904
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901791233534084
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9909360912930099
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900732329018881
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902557371452615
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904632322379908
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911055518240979
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900810888386057
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9909371030637092
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899384980314136
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.992887542461256
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898407970764805
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990451324498571
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901870879529691
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894430894057769
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9916295295026074
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894709980696019
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912392791968301
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893712091992635
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904454976260914
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894208660989937
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989362310550173
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902998438077989
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895377304060851
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896241056800963
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906102153764267
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896472060098054
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906650494000442
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899294911935741
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902903745450655
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902752578902274
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897746049259927
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990348149787922
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899848713271159
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903164593376195
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899299685657669
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907203065698895
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989987740410163
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905728796634776
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901201520237423
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893623873719407
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907203934745402
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912125778516608
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912298763018672
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913387593541723
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9920365152226329
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905404258812611
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903912574603644
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903161286814417
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893623139589497
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899334964858718
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904904963926302
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.99020027007446
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910077467710996
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903694087003087
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900667354375752
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896397042546324
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914584846935351
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902848525458282
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.99045341771363
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894783542693885
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9909379085450039
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896399055090326
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902927179495802
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9909878670204975
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902690281744386
# ...
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902899499507452
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914642754310639
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896411633251134
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911678209537191
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896976714160517
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899144485152651
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904203307877448
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895413809623543
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9916059003650244
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.98936231395895
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899513266715023
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908274013127552
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895551432115067
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907001643668931
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913430907136145
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896424973046686
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899561522433519
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911070986583383
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899514883123939
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906109683200411
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901513062891296
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910569602682174
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914319595152511
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904570946072558
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903675937582817
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913641671629665
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894938534686197
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900474032661848
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899004092100416
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.99050454963857
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903285809248211
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893631930899341
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907890393837748
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913076861368737
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896988683782926
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904626735546053
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902622716314579
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900759275491658
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893764892829882
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906577161755725
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893626631972656
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903526004161389
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.99036930382055
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9879475067547143
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899498584087962
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903391596269409
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911211922349799
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9909479670037983
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902356890702311
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9916176125383607
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899790651108281
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894201809662093
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902002252692892
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9884564942200816
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908072703310007
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896373377502315
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903094727896994
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903623470295289
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910312151481052
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989672037900891
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898340301635742
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904344620520944
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9930453678849938
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896510647712473
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898300662732262
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893863268834074
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896510195075574
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906371621673236
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910890901592837
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905531455608764
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895310827128305
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989914543245768
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905809696581988
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893764894868561
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902677403547837
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899186116249977
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990165413199027
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.991912596399725
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904628522885729
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903633700554877
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989482754837589
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899329212550264
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898887585034268
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905348071927627
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893634023074924
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893689616362211
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905950787893327
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893623083963812
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898077549909708
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899956546207577
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903416622210577
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990502216572332
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893823553077377
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907452166556571
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9917677210141191
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895310902461267
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.991305553632177
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902647160694
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896155933473781
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899816544228561
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898215664754197
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899815109958234
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893625415694396
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910780844809055
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.99096530981719
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989545527741623
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905086564525739
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898219658061091
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910982848158558
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897940914164807
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905726387287223
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897731301637117
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903328847579167
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901216482201736
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904608015396683
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896440375431276
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905262314402028
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893863522309181
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896514690303011
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9921650942621977
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893636210147791
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990252437627665
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908034173144791
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901597074628501
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899461978242406
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895399638860678
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906456455973811
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895023287125264
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893623532173975
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9909447534484351
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907942359131796
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899053681734578
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989478338980897
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914821263079545
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908063471744009
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893689616362211
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896757377253526
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914032671409049
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899144507889182
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896711377476421
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9920045862231556
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898409330273602
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901454910165662
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906994810983274
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913064567345331
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896866599521768
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896132730801344
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.991039824688439
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907047974308602
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989531111990767
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895482318488663
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989362308396371
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897148482442505
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911732934364752
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914606051682174
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989627849446106
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9909025105982182
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898399432919793
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908817721276033
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904306010277439
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912242039974504
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911106460000567
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902647216319295
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897047856126633
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.991070578503552
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893623371673601
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902242062438961
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913212151411073
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9917173678395261
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911101537718676
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895023233695783
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901200055195294
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908896214441885
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902157476093735
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898980660945167
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904904582714104
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894777280113758
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895654284086889
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896278331922619
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907614207306102
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899091862490927
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910646766874842
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913823896809147
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9915652219233722
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9909921743229136
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898113569067023
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905415586933342
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907491374708746
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893667873262835
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898648149536243
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899145594357173
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908423941710955
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903462925693679

# %%
plt.plot(all_raster_kde['x'], estimated_medians)
plt.fill_between(all_raster_kde['x'], estimated_q5s, estimated_q95s, alpha =0.4)

plt.plot(all_raster_kde['x'], baseline_medians, color = 'black', lw = 1.5)
plt.fill_between(all_raster_kde['x'], baseline_q5s, baseline_q95s, color = 'lightgray', zorder = -100)

# %%
# export the median, quartiles, etc to file

bootstrap_kde = dict(
    x = all_raster_kde['x'], 
    baseline_median = baseline_medians,
    baseline_q5 = baseline_q5s, 
    baseline_q95 = baseline_q95s,
    estimated_median = estimated_medians, 
    estimated_q5 = estimated_q5s,
    estimated_q95 = estimated_q95s
)

bootstrap_kde = pd.DataFrame(bootstrap_kde)
bootstrap_kde.to_csv('../processed_data/kde_bootstrap.csv')

# %% [markdown]
# Export distance KDE

# %%
# make kdes for all
bandwidth = 0.01

# convert to numpy arrays
all_veloc = np.asarray(all_veloc)
dyad_veloc = np.asarray(dyad_veloc)
event_veloc = np.asarray(event_veloc)

# compute kde of velocities
kde_v_all = gt.utils.kde1d(all_veloc[~np.isnan(all_veloc)], bandwidth)
kde_v_interact = gt.utils.kde1d(dyad_veloc[~np.isnan(dyad_veloc)], bandwidth)
kde_v_events = gt.utils.kde1d(event_veloc[~np.isnan(event_veloc)], bandwidth)

kde_v_all = dict(x=kde_v_all[0], y = kde_v_all[1])
kde_v_interact = dict(x=kde_v_interact[0], y = kde_v_interact[1])
kde_v_events = dict(x=kde_v_events[0], y = kde_v_events[1])

kde_v_all = pd.DataFrame(kde_v_all)
kde_v_interact = pd.DataFrame(kde_v_interact)
kde_v_events = pd.DataFrame(kde_v_events)

kde_v_all.to_csv("../processed_data/kde_v_all.csv")
kde_v_interact.to_csv("../processed_data/kde_v_interact.csv")
kde_v_events.to_csv("../processed_data/kde_v_events.csv")
# Out:
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 1.0118666359165367
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9968494797949562
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911281499297891
