# %% [markdown]
# Compute distances for distance KDE

# %%
# setup
import gridtools as gt
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import numpy as np
import pandas as pd
# %matplotlib qt

from plotstyle import PlotStyle

s = PlotStyle()
dataroot = "../output/"
eventstats = pd.read_csv(dataroot + "eventstats.csv")
recs = gt.ListRecordings(dataroot)

# compute distance kde's
all_distances = []
dyad_distances = []
event_distances = []
n_all = 0
n_interact = 0
n_events = 0

for recording in recs.recordings:
    datapath = recs.dataroot + recording + "/"
    grid = gt.GridTracks(datapath, finespec=False)
    events = pd.read_csv(datapath + "events.csv")

    # get all distances
    n_all += len(grid.ids)
    dyad_ids = gt.utils.unique_combinations1d(grid.ids)
    for ids in dyad_ids:
        dyad = gt.Dyad(grid, ids)
        if dyad.overlap is True:
            all_distances.extend(dyad.dpos.tolist())

    # get unique interacting dyad distances
    dyads = []
    uniq1 = list(np.unique(events.id1))
    uniq2 = list(np.unique(events.id2))
    all_ids = np.unique(np.append(uniq1, uniq2))
    n_interact += len(all_ids)

    for idx in events.index:
        dy = sorted([events.id1[idx], events.id2[idx]])
        dyads.append(dy)
    unique_dyads = [list(x) for x in set(tuple(x) for x in dyads)]
    for ids in unique_dyads:
        dyad = gt.Dyad(grid, ids)
        if dyad.overlap is True:
            dyad_distances.extend(dyad.dpos.tolist())

    # get distances during events
    for idx in events.index:
        dyad = gt.Dyad(grid, [int(events.id1[idx]), int(events.id2[idx])])
        start = gt.utils.find_closest(dyad.times, float(events.start[idx]))
        stop = gt.utils.find_closest(dyad.times, float(events.stop[idx]))
        event_distances.extend(dyad.dpos[start:stop].tolist())
        n_events += 1

# convert to numpy arrays
all_distances = np.asarray(all_distances)
dyad_distances = np.asarray(dyad_distances)
event_distances = np.asarray(event_distances)
# Out:
# [ GridTracks.__init__ ] No grid metadata found in directory ../output/2016-04-20-18_49/
# [ GridTracks.__init__ ] No grid metadata found in directory ../output/2016-04-18-19_22/
# [ GridTracks.__init__ ] No grid metadata found in directory ../output/2016-04-16-18_45/
# [ Dyad.__init__ ] Supplied identities do not share a common overlap!
# [ Dyad.__init__ ] Supplied identities do not share a common overlap!
# [ Dyad.__init__ ] Supplied identities do not share a common overlap!
# [ Dyad.__init__ ] Supplied identities do not share a common overlap!
# [ Dyad.__init__ ] Supplied identities do not share a common overlap!
# [ Dyad.__init__ ] Supplied identities do not share a common overlap!
# [ Dyad.__init__ ] Supplied identities do not share a common overlap!
# [ Dyad.__init__ ] Supplied identities do not share a common overlap!
# [ GridTracks.__init__ ] No temperature an light data found in directory ../output/2016-04-09-22_25/.
# [ GridTracks.__init__ ] No grid metadata found in directory ../output/2016-04-09-22_25/
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__ ] Supplied identities do not share a common overlap!
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__ ] Supplied identities do not share a common overlap!
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__ ] Supplied identities do not share a common overlap!
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__ ] Supplied identities do not share a common overlap!
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__ ] Supplied identities do not share a common overlap!
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__ ] Supplied identities do not share a common overlap!
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.

# %%
# make kdes for all
xlims_dpos = [0, 400]
bandwidth = 10

# compute kde
kde_d_all = gt.utils.kde1d(all_distances, bandwidth, xlims_dpos)
kde_d_interact = gt.utils.kde1d(dyad_distances, bandwidth, xlims_dpos)
kde_d_events = gt.utils.kde1d(event_distances, bandwidth, xlims_dpos)

kde_d_all = dict(x=kde_d_all[0], y = kde_d_all[1])
kde_d_interact = dict(x=kde_d_interact[0], y = kde_d_interact[1])
kde_d_events = dict(x=kde_d_events[0], y = kde_d_events[1])

kde_d_all = pd.DataFrame(kde_d_all)
kde_d_interact = pd.DataFrame(kde_d_interact)
kde_d_events = pd.DataFrame(kde_d_events)

kde_d_all.to_csv("../processed_data/kde_d_all.csv")
kde_d_interact.to_csv("../processed_data/kde_d_interact.csv")
kde_d_events.to_csv("../processed_data/kde_d_events.csv")
# Out:
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9979630526210534
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9934363360970784
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9558349107146368

# %% [markdown]
# Export up-modulation during Events for initiators as reactors (data and KDE)

# %%
resting_init = []
resting_react = []
max_init = []
max_react = []
diff_resting_withstatus = []
diff_resting = []

for idx in eventstats.index:
    init_id = float(eventstats.initiator[idx])

    diff_resting.append(abs(eventstats["restingf_id1"][idx] - eventstats["restingf_id2"][idx]))
    if np.isnan(init_id) == False:
        
        if int(init_id) == eventstats.id1[idx]:
            resting_init.append(float(eventstats.restingf_id1[idx]))
            max_init.append(float(eventstats.maxeventf_id1[idx]))
            resting_react.append(float(eventstats.restingf_id2[idx]))
            max_react.append(float(eventstats.maxeventf_id2[idx]))
        
        elif int(init_id) == eventstats.id2[idx]:
            resting_init.append(float(eventstats.restingf_id2[idx]))
            max_init.append(float(eventstats.maxeventf_id2[idx]))
            resting_react.append(float(eventstats.restingf_id1[idx]))
            max_react.append(float(eventstats.maxeventf_id1[idx]))
        
        diff_resting_withstatus.append(abs(eventstats["restingf_id1"][idx] - eventstats["restingf_id2"][idx]))

resting_init = np.asarray(resting_init)
resting_react = np.asarray(resting_react)
max_init = np.asarray(max_init)
max_react = np.asarray(max_react)

resting_initreact_diff = resting_init - resting_react
kde_f_restinginitreact_diff = gt.utils.kde1d(resting_initreact_diff, 2)

init_amp = max_init - resting_init
react_amp = max_react - resting_react

xlims = [0, 50]
kde_react_amp = gt.utils.kde1d(react_amp, 1, xlims)
kde_init_amp = gt.utils.kde1d(init_amp, 1, xlims)

event_f_increase = dict(init=init_amp, react=react_amp)
event_f_increase = pd.DataFrame(event_f_increase)
event_f_increase.to_csv("../processed_data/event_f_increase.csv")

kde_react_increase = dict(x=kde_react_amp[0], y=kde_react_amp[1])
kde_react_increase = pd.DataFrame(kde_react_increase)
kde_react_increase.to_csv("../processed_data/kde_react_increase.csv")

kde_init_increase = dict(x=kde_init_amp[0], y = kde_init_amp[1])
kde_init_increase = pd.DataFrame(kde_init_increase)
kde_init_increase.to_csv("../processed_data/kde_init_increase.csv")
# Out:
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9328044712312922
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9999999861049931
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9999999977347609

# %% [markdown]
# Get delta f of dyads before and during events

# %%
diff_resting = abs(eventstats["restingf_id1"] - eventstats["restingf_id2"])

diff_f_before_vs_during_event = dict(before=diff_resting, during=eventstats["diff_medianevent"])
diff_f_before_vs_during_event = pd.DataFrame(diff_f_before_vs_during_event)
diff_f_before_vs_during_event.to_csv("../processed_data/diff_f_before_vs_during_event.csv")

# %% [markdown]
# Extract resting initiator ID - resting reactor ID

# %%
resting_init = []
resting_react = []
max_init = []
max_react = []
diff_resting_withstatus = []
diff_resting = []

for idx in eventstats.index:
    init_id = float(eventstats.initiator[idx])

    diff_resting.append(abs(eventstats["restingf_id1"][idx] - eventstats["restingf_id2"][idx]))
    if np.isnan(init_id) == False:
        
        if int(init_id) == eventstats.id1[idx]:
            resting_init.append(float(eventstats.restingf_id1[idx]))
            max_init.append(float(eventstats.maxeventf_id1[idx]))
            resting_react.append(float(eventstats.restingf_id2[idx]))
            max_react.append(float(eventstats.maxeventf_id2[idx]))
        
        elif int(init_id) == eventstats.id2[idx]:
            resting_init.append(float(eventstats.restingf_id2[idx]))
            max_init.append(float(eventstats.maxeventf_id2[idx]))
            resting_react.append(float(eventstats.restingf_id1[idx]))
            max_react.append(float(eventstats.maxeventf_id1[idx]))
        
        diff_resting_withstatus.append(abs(eventstats["restingf_id1"][idx] - eventstats["restingf_id2"][idx]))

resting_init = np.asarray(resting_init)
resting_react = np.asarray(resting_react)
max_init = np.asarray(max_init)
max_react = np.asarray(max_react)

resting_initreact_diff = resting_init - resting_react
kde_f_restinginitreact_diff = gt.utils.kde1d(resting_initreact_diff, 2)

resting_initreact_diff = dict(diff_resting = resting_initreact_diff)
resting_initreact_diff = pd.DataFrame(resting_initreact_diff)
resting_initreact_diff.to_csv("../processed_data/diff_f_init_react.csv")

kde_f_restinginitreact_diff = dict(x=kde_f_restinginitreact_diff[0], y=kde_f_restinginitreact_diff[1])
kde_f_restinginitreact_diff = pd.DataFrame(kde_f_restinginitreact_diff)
kde_f_restinginitreact_diff.to_csv("../processed_data/kde_f_restinginitreact_diff.csv")
# Out:
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9328044712312922

# %% [markdown]
# Extract physical interaction events for initiators, reactors and total and appropriate time axis.

# %%
all_veloc = []
dyad_veloc = []
event_veloc = []
event_interactions_init = []
event_interactions_react = []
event_interactions = []
event_interactions_ts = []
event_durations = []

for recording in recs.recordings:
    datapath = recs.dataroot + recording + "/"
    grid = gt.GridTracks(datapath, finespec=False)
    events = pd.read_csv(datapath + "events.csv")

    # get all distances
    for track_id in grid.ids:
        t = grid.times[grid.idx_v[grid.ident_v == track_id]]
        x = grid.xpos_smth[grid.ident_v == track_id]
        y = grid.ypos_smth[grid.ident_v == track_id]
        v = gt.utils.velocity2d(t, x, y)
        all_veloc.extend(v.tolist())

    # get unique interacting dyad distances
    dyads = []
    uniq1 = list(np.unique(events.id1))
    uniq2 = list(np.unique(events.id2))
    all_ids = np.unique(np.append(uniq1, uniq2))
    for track_id in all_ids:
        t = grid.times[grid.idx_v[grid.ident_v == track_id]]
        x = grid.xpos_smth[grid.ident_v == track_id]
        y = grid.ypos_smth[grid.ident_v == track_id]
        v = gt.utils.velocity2d(t, x, y)
        dyad_veloc.extend(v.tolist())

    # get data during events
    for idx in events.index:

        # extract all positions for kde
        dyad = gt.Dyad(grid, [int(events.id1[idx]), int(events.id2[idx])])
        start = gt.utils.find_closest(dyad.times, float(events.start[idx]))
        stop = gt.utils.find_closest(dyad.times, float(events.stop[idx]))

        t = dyad.times[start:stop]
        x1 = dyad.xpos_smth_id1[start:stop]
        x2 = dyad.xpos_smth_id2[start:stop]
        y1 = dyad.xpos_smth_id1[start:stop]
        y2 = dyad.xpos_smth_id2[start:stop]

        v1 = gt.utils.velocity2d(t, x1, y1)
        v2 = gt.utils.velocity2d(t, x2, y2)

        v = np.append(v1, v2)
        event_veloc.extend(v.tolist())

        # get event edurations
        dur = dyad.times[stop]-dyad.times[start]

        # extract social events for event triggered interactions

        # get approx 5 minutes before event start and 10 minutes after event start
        start2 = start - 1000
        stop2 = start + 2000

        t_rasterplot = dyad.times[start2:stop2] - dyad.times[start]
        
        peakprom = 1
        maxd = 25

        peaks1, peaks2 = gt.utils.find_interactions(dyad, start2, stop2, maxd=maxd, peakprom=peakprom)
        peaks = np.append(peaks1, peaks2)

        # detect interactions for intiators and reactors
        if events.init[idx] == events.id1[idx]:
            peaks_init, peaks_react = gt.utils.find_interactions(dyad, start2, stop2, maxd=maxd, peakprom=peakprom)
            event_durations.append(dur)
        elif events.init[idx] == events.id2[idx]:
            peaks_react, peaks_init = gt.utils.find_interactions(dyad, start2, stop2, maxd=maxd, peakprom=peakprom)
            event_durations.append(dur)
        else:
            continue

        # append to list    
        event_interactions_init.append(peaks_init)
        event_interactions_react.append(peaks_react)
        event_interactions.append(peaks)


# convert to numpy arrays
t_rasterplot = np.asarray(t_rasterplot)

# sort events by syncrhonized duration in reverse order, then sort duration
event_interactions_init = [x for _, x in sorted(zip(event_durations, event_interactions_init), key=lambda pair: pair[0], reverse=True)]
event_interactions_react = [x for _, x in sorted(zip(event_durations, event_interactions_react), key=lambda pair: pair[0], reverse=True)]
event_interactions = [x for _, x in sorted(zip(event_durations, event_interactions), key=lambda pair: pair[0], reverse=True)]

# sort event durations as well
event_durations.sort(reverse=True)
# Out:
# [ GridTracks.__init__ ] No grid metadata found in directory ../output/2016-04-20-18_49/
# [ GridTracks.__init__ ] No grid metadata found in directory ../output/2016-04-18-19_22/
# [ GridTracks.__init__ ] No grid metadata found in directory ../output/2016-04-16-18_45/
# [ GridTracks.__init__ ] No temperature an light data found in directory ../output/2016-04-09-22_25/.
# [ GridTracks.__init__ ] No grid metadata found in directory ../output/2016-04-09-22_25/
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.
# [ Dyad.__init__  ] GridTracks instance has no temperature and light arrays.

# %% [markdown]
# Make kde for interaction events rasterplot, i.e. event onset triggered interactions and transform peak indices to timestamps

# %%
# make kde for interaction events rasterplot, i.e. event onset triggered interactions
bandwidth = 10
#event_interactions_flat = np.concatenate(event_interactions)

# flatten data
init_flattened = np.concatenate(event_interactions_init)
react_flattened = np.concatenate(event_interactions_react)
all_flattened = np.concatenate(event_interactions)

# make flattened timestamps
init_ts = t_rasterplot[init_flattened]
react_ts = t_rasterplot[react_flattened]
all_ts = t_rasterplot[all_flattened]

# calculate separate kdes:
init_raster_kde = gt.utils.kde1d(init_ts, bandwidth, [np.min(t_rasterplot), np.max(t_rasterplot)])
react_raster_kde = gt.utils.kde1d(react_ts, bandwidth, [np.min(t_rasterplot), np.max(t_rasterplot)])
all_raster_kde = gt.utils.kde1d(react_ts, bandwidth, [np.min(t_rasterplot), np.max(t_rasterplot)])

# save kdes to file
init_raster_kde = dict(x=init_raster_kde[0], y=init_raster_kde[1])
react_raster_kde = dict(x=react_raster_kde[0], y=react_raster_kde[1])
all_raster_kde = dict(x=all_raster_kde[0], y=all_raster_kde[1])

init_raster_kde = pd.DataFrame(init_raster_kde)
react_raster_kde = pd.DataFrame(react_raster_kde)
all_raster_kde = pd.DataFrame(all_raster_kde)

init_raster_kde.to_csv('../processed_data/kde_raster_init.csv')
react_raster_kde.to_csv('../processed_data/kde_raster_react.csv')
all_raster_kde.to_csv('../processed_data/kde_raster_all.csv')

# make timestamp matrices
raster_ts_init = []
raster_ts_react = []
raster_ts_all = []
for init, react, interact in zip(event_interactions_init, event_interactions_react, event_interactions):
    rti = t_rasterplot[init]
    rtr = t_rasterplot[react]
    rta = t_rasterplot[interact]
    raster_ts_init.append(rti)
    raster_ts_react.append(rtr)
    raster_ts_all.append(rta)

# save timestamp matrices
np.save("../processed_data/raster_ts_init.npy", raster_ts_init, allow_pickle=True)
np.save("../processed_data/raster_ts_react.npy", raster_ts_react, allow_pickle=True)
np.save("../processed_data/raster_ts_all.npy", raster_ts_all, allow_pickle=True)
# Out:
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899438573306721
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9941783933566748
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9941783933566748
# /home/weygoldt/Data/uni/efish/env/lib/python3.10/site-packages/numpy/lib/npyio.py:518: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = np.asanyarray(arr)

# %% [markdown]
# Jigsaw and resampling

# %%
# extract event df
bandwidth = 10

nsamples = len(all_ts) # all timestamps, i.e. all interaction events
nresamples = 10000

all_ts = sorted(all_ts)
# plt.eventplot(all_ts)

diffs = np.diff(all_ts, prepend = all_ts[0])

print(f'timestamp length: {len(all_ts)}')
print(f'diffs length: {len(diffs)}')

print(f'timestamps: {all_ts[0:10]}')
print(f'diffs: {diffs[0:10]}')

kdes = [] # collect kdes here

# resample
for i in range(nresamples):

    # shuffle randomly
    np.random.shuffle(diffs)

    # make shuffled to timestamps starting with first time point
    randevents = np.concatenate(([t_rasterplot[0]], diffs)).cumsum()

    # compute kde
    randkde = gt.utils.kde1d(randevents, bandwidth)

    # stash kde
    kdes.append(randkde[1])

# compute median
kdes = np.asarray(kdes)
plt.plot(all_raster_kde['x'], all_raster_kde['y'], color = 'red', lw = 3)

baseline_medians = np.median(kdes, axis = 0)
baseline_q5s = np.quantile(kdes, 0.05, axis=0)
baseline_q95s = np.quantile(kdes, 0.95, axis=0)
# Out:
# timestamp length: 561
# diffs length: 561
# timestamps: [-326.6954499999956, -325.3846499999963, -319.15889999999854, -316.537849999997, -316.537849999997, -315.5547499999957, -315.2270499999977, -314.89934999999605, -310.9669499999982, -310.9669499999982]
# diffs: [0.      1.3108  6.22575 2.62105 0.      0.9831  0.3277  0.3277  3.9324
#  0.     ]
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9890245154568117
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9788257088062856
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907736983653211
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9927313035935447
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906236640603887
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9953080671696888
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911244508194998
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9865361143597603
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9919370342569402
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9922100004780361
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9930703153574588
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9891899102849346
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.988793205657509
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9915132118257957
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9891959665227752
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9857972786392317
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9927188108349129
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897772036714594
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9855868884657084
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9875675508994634
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9845352179671264
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9850585894847208
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.982026192584768
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9889576801571929
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9917075614381292
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9875938901523416
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9944027717335844
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913315163529207
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902692731604489
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9880198834317421
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9842706028349552
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.98931799378041
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9879707114977081
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9887305045520067
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9876910222833435
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.988237186696814
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899650145015491
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9889318232265812
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9922345398512962
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9916025652521051
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894206508227994
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9937112132116949
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9865775168255841
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9881172435022738
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9838184134454906
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.988271818069796
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9873862440273695
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9875141162110385
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9882989722728719
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9879175346383224
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912807909746307
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912455218151718
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9884390891774861
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9934096831151107
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9868824828470295
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9915823548521003
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9823725109902632
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911135933297783
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9881689099589572
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9922721311014214
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9922181021513691
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913475580681412
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.98790143054285
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9876655763635568
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9892571054398719
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899260033376223
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894160394918448
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9882924834587434
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9849768686540248
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9890355171793311
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9860061095677368
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9921034195000633
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893319993784245
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9890374542894764
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9909601877171856
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9909826015698626
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914550998739875
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9886745603781186
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9883595572080635
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903903323713527
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898201434833125
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9926651981284165
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9909499472326428
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9968733049383046
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899431852958551
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9877164468379049
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904337419640792
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9947679009637943
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914071683073333
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.992667876296878
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9917606023246354
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9878726290833908
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9852222436998205
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9871719272017643
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9880140027067632
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9882970458162075
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904724753829004
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9931296663864009
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.988464338491307
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9864272926481986
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9915178371233427
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9835864491780202
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912463255699995
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9928536104077353
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9887288128208944
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9916338051734683
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913388369199351
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9883009605873221
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9938442172926221
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9884648553425383
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9880718527214756
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914884146818119
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903624559546377
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9866664304004565
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9864433592235727
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9881341760035394
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.98973220585109
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893792968390396
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896173530516028
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908897637194984
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.985821205238042
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9879133455773682
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9865923529147649
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906382616545761
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9876132927839254
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9876834714493814
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895013909207994
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906206343033337
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905863037604778
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9917535150105192
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9869830165037605
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9876751982943452
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9872274827050705
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9869435724699468
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9877300004067466
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9848553915078284
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9889818851356174
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9864316502826352
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9867507197005659
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9875232759354842
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9852178165800265
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9887460815878371
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9877880730637008
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896971383940034
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9916570085139236
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9874522111997518
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910446450791515
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9880843015655444
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9932077462341002
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9944746028649247
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9884919812136679
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913362051415959
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9916999086957552
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989366542203429
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903791618639102
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9927541936052477
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9922840554247624
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9859796153781358
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913976049761836
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.991126335958266
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898779275881631
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.987687128217398
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.992847312978991
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9885176496414849
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9888124770082607
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9884020946991068
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9877486002386245
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.988825349559384
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9867972522669585
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9861122881145183
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9871356313941053
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9866978903828747
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9889946965917471
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9873627789114259
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913119944622275
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9871783835937188
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.988104622408344
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904449141681041
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902451664626671
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907729202474396
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9886638472130472
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9867121723544514
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895359538007681
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9929030158911473
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908728985041209
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9884716326630314
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9857391466641525
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9882475624572364
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913205957522924
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902556244316604
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9841925219268595
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9929057781382629
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907166567755903
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904096151508903
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9889120822014621
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9890283555736471
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899803944548875
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9876255478104311
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9890234071901844
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9861799000172273
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911902794080878
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.988094553123632
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9917637108886443
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990496024519187
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9923659947179404
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9867974578870293
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9939448159164512
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9868202044972225
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9888893745589591
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898234483528916
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9928688232146489
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9852994271177152
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9871184439665357
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898731423100324
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9918951645904481
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907659451360417
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9876717709912075
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9922524812797634
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.991153541499069
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9916705960597174
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9887323562420294
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9844156820369204
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9880978346913808
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.987168618707208
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914235617624785
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9854959304256021
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9940520026915054
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9867875676320356
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9884248472495634
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9916219877792489
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9877024931812238
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9883987008847295
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910031257469076
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9844248594035874
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9881574605857159
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9887952407158663
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9843470423115466
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9879292078042514
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9871786388048404
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9926883411285581
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9860344006817268
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899556612039963
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9881017100699057
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9884255869225615
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9846271092824183
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907722433414372
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.995686510850216
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9878346599339936
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9815472275738489
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9874489171759679
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9867141415485338
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9927404350002095
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9889106819327702
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9851604415252863
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9936428726933537
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9924137756914495
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9930993706616779
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911557889733007
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9885167893328257
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914845413880473
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9923757112777455
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911532984973366
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9827297957442371
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897501758707382
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9876097907295858
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9888124087358661
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9875412073092662
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9945946583409432
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9881618770601129
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9843949354882354
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989815936008791
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912245416601153
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9890400778794703
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9861305174102717
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9915805311977395
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898513401458846
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989592288425806
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.991364828262243
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.986318855922494
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901620124688444
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9871674401064052
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.985371633823733
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9890751210859238
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9844733584872132
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9917804370014652
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899480247220277
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914755360492845
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9936225878988083
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9920448472806574
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9877042294691762
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896917964245772
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913798544616377
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9857824246185205
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900392128411201
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9848237859497898
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9885748877882029
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894080784856312
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9920503922413019
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990278776046579
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9862471986609342
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902272583467142
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9965972891722794
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9875570686732319
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9837827120072239
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901245378922207
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.986775986887422
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914229865323353
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9844200482393433
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9920721991600145
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9886269872422306
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9879096866708634
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9859463461998559
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893743333407984
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9859572044206195
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.992548843425526
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9887315671910166
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9882182810808109
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9931207252605353
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.99075885026988
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910901426911626
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893538471625907
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9876365264757218
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9825793388784447
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904951818523617
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990106781845534
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896198242819276
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9869644585448917
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.987889504846562
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.988498138974394
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9862985974624505
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9872832642136261
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897205717064481
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9877162318307696
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898309091519374
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.992062955648805
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9883877732246561
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911123289054133
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9942625508261458
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9959426543617973
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9920626281271498
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9863387718422446
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9932945461169155
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9869127310698623
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9880834086882736
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9889951851620546
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9884804785833285
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900353436137543
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9939224373844929
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9929573019340361
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.988041574623994
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.988314397236876
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914167830694093
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9847246579666138
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9892390419276444
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9861264745610425
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9891945404723749
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9916938695033977
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9886985471580356
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896620569045286
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911501248422299
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914372715593789
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895813872746948
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9864172553087935
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894824569118722
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9876940400878729
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914885802855844
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905614736412636
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900253587451604
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900207101279221
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9872025490122791
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899067720732766
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9909181437358794
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.992186139130036
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9931330320089953
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9876269278337962
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912148435628862
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9860674532707969
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9920896584876999
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9889325190743941
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9853956534777846
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9872827913513612
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9849680840247129
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9928230159935864
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907866153588991
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893481533304433
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9887403228071536
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9952491180049285
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895754377610122
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9882184654575075
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9863180987348348
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898755286333574
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9832040839924957
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9859227802909305
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9871374796287398
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9955220683995392
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9890041930266495
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9878860944004599
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9939237289883793
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9868480217436382
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9936241746473093
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.993690053838501
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9833264305224352
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.985351517030703
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904440974210176
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.993827468620988
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9836134673476715
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907786021621704
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902661131436508
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9850450402722996
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9836995940371058
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.986789777345823
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899469233709741
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.991695525951634
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894523967667673
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9858234470997291
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898245360030389
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911066051778776
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9915750243421123
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894520523775853
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9917783231353972
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911646920353583
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9952964124702819
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9884475119912808
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.987867413165473
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9877369379756505
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9847509644615906
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9934512405716484
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9862248681461342
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9892530744617045
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908333256351323
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9928519218160297
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9892674139498098
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9924819155166502
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.991834197199756
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904228858809518
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901486393099106
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903282271689026
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904874874268206
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9886705158873883
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9919074405482464
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9863417093651348
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9877977141450247
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9928675835536684
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9883802979019068
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9961103454939766
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989787600382553
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9858099148748949
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908454747452577
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9935873999889221
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898991529673267
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9921067659007708
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9849306135100556
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.98878545388531
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9909419063738852
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.98448937091946
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.984396693187377
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9889604767957474
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9883873225864719
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9873053770659517
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9876003539315449
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9889767773841088
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907585716261842
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9883754775733911
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.982209426858955
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9920208078772644
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9886729628487978
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9886650003878813
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9892330761689516
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9861522059172878
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989505736500855
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.987720605914979
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9917859096819528
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9918438291742644
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9807528476248992
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9885463509986353
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913332445991366
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9932651329173513
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9841895120755301
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9888447605129294
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9889551519645783
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.99132397040314
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9886265073981741
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9856881503349684
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913945409212827
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9863512941035333
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9839776770425273
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899797396249103
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906882405064971
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.986309229477639
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9874085792036291
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893781395323817
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907871329367692
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903143411674591
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9863420590967704
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9936956882431858
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989277409303642
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896157017884583
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9872688184585089
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899058131239983
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9851251102318459
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9862802571246668
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9917012395938
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9891598169150295
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9892158657406223
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9824057770913858
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9884385190028679
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9867102567679457
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9879779879033747
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899598421947614
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9920867080062984
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906314226774845
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9890724190515493
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9868813082113899
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9855015017466271
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9882657869678839
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9926457204956405
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893097857744562
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9933880861277953
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9934103325707496
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9888484761929213
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9869128208093172
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912340313857123
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9845404880979503
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989332151741855
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.987150736058559
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902249995217842
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9853197770288147
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9869409003897908
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9859097919593388
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9859081059332472
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9945885407133447
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9884822084462084
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9918522660109959
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9847984259830749
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9858762274515602
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9875961291474729
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9856600167027311
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900964520756403
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9859394392189621
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9874145178825765
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9861824565765049
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9973519551906331
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9856884552727703
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913931250563855
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9864841051969335
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9934700317201444
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901079376232073
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9849015262959282
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9890180362726524
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901082561771309
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9860231198700075
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902935526443786
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907261803807302
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9872210949327221
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9932003894025921
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894815036219851
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9883717918638896
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9838201044789425
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914964810560851
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907589376596193
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9883049151611765
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9881670211549287
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9872718963269109
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897665815856878
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9842469239433842
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.98729641168361
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9915096616247661
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903717929185256
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.991297547300413
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893050921872384
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.992112746588854
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905811236429416
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.987660039202719
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9874664410635632
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9825562427900778
# ...
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9872611315022375
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9810902576608413
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9928701619418855
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9834776557111787
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9868558005346051
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9875233707767981
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9858809256266654
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904558511336217
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9869162032973717
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9833076095211739
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9884098260968733
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.988163936340337
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9857528259450389
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9887814468349956
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899081972511335
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9854530563919897
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9889266231638814
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9927652314964563
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914163510576017
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894626320450621
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9883694132853168
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904720517985999
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902572924815777
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911629558600092
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9848808975534482
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9850994620274757
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896022053538046
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9879154812533442
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9879556924913395
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9883482802336465
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9830092385926766
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9929755971816328
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9917734704727792
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9879981992248668
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.987393236095251
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899922424789231
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911393881205215
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9921994062010223
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9891459190450018
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990264936952341
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893565432115496
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9872866042873596
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894893289136113
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908612340507024
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897640053610811
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902279743103877
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9875194479115688
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.991501919920024
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902105070750937
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913689355953881
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9890912589654662
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898956296347763
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9886124479124676
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900073296139451
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9923978987945375
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896272396529073
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9916978478351726
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9865745363569574
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904966511049909
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9876589539296601
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9885603225338135
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912787745441227
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9862189382744099
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9943349112047293
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9888181912193728
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9856138240990218
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910727658332176
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9830227782066255
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914280138856497
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896661889332852
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9869861085609506
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908866775333831
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.991857539076223
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9925273127474669
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9856633459824606
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9876489342228539
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903697997153716
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.987447279132537
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.98800057990445
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9933739997688806
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9919156374931916
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9878781366430663
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9920990203099175
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.984845454587578
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9923256923656132
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9927474048160171
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9921511632676027
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9867323399589631
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910282810003841
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895676728490248
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898375622464125
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9933188588607424
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9807897950306959
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9886745974027085
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895781153995584
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9928973762404789
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912253101002826
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9881219918909422
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9861411978075612
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9873251679377474
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9892040614570113
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990879253927224
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9886940940186703
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9841549435167469
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9839048003498296
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910673370602756
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893284441718946
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900174979098011
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9889727265486083
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9930765708260253
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9861539498729649
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9873309155100726
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9885412886130993
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9838428502213759
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9873017140383153
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9918424765466161
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9887192047814752
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900154234541176
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893639723382782
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9892958336475504
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9892682555093897
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9888216311861555
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9925568857725338
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9927743669498302
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9916958422782569
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9931278566543675
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9891394687637672
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9928196041605706
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9918079954097015
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913120121462001
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9868694329317783
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9916211854679229
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9940902037912642
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9886806611703387
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9883455965086487
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9853639770545795
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912470760979688
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9856370364659355
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9851710522096355
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9860229190431519
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9939353502765549
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9837636524898039
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9881808128713464
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.991729904279629
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989654492099654
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911611017428041
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9863546003874508
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9839615166204738
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990490249044617
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9888457829373501
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9949889483424875
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9915104747960808
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9938203909262777
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9819188969884328
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9865715430816584
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913511592590059
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900297888961609
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9937861471360736
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.992088540337628
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9886716402615647
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9887699540620455
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9892893088408057
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9917661159736617
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9891207327753035
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904577293212276
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9891320343246104
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9889977476968036
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896424488745894
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9856857828179757
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900950829448985
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9892232910335861
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9870294824593943
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905557116334393
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9922790879267225
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9860336332748502
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.98476586498497
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906299497971627
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903825529208239
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9924136770030988
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9886258391060632
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.986353823159092
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903487425571538
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.991395451382199
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989500510786204
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9858604321626958
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9873636221581137
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.98966681029921
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9855373127923674
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9866079642663557
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9927380847034091
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9870431516219265
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9926980007814481
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9862978545605166

# %% [markdown]
# Jackknife

# %%
bandwidth = 10

nsamples = len(all_ts) # all timestamps, i.e. all interaction events
nresamples = 10000

all_ts = sorted(all_ts)
# plt.eventplot(all_ts)

kdes = []
subsetsize = int(0.9 * len(all_ts))

# resample
for i in range(nresamples):

    # compute kde
    randkde = gt.utils.kde1d(np.random.choice(all_ts, subsetsize, replace = False), bandwidth)

    # stash kde
    kdes.append(randkde[1])

estimated_medians = np.median(kdes, axis = 0)
estimated_q5s = np.quantile(kdes, 0.05, axis=0)
estimated_q95s = np.quantile(kdes, 0.95, axis=0)
# Out:
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897873051105137
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904640415246939
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896954420051275
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9915888110204854
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989400615350524
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907008452705262
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893832219488715
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894200100407907
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896412323553536
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901214120107876
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905177563830252
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904566753988837
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910811553309004
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903118501570093
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896756006372954
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898205218167193
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912266948616952
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893689616362211
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912190258326687
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895427102179369
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898842270002491
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.98978757674693
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.988445666651787
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.98981123014024
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894253934260664
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896373684572187
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897047568574273
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913331843895723
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911502323912011
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9916735623014922
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895310941631661
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900836893035884
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911170740919077
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9919790763719779
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903285996709141
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913459302244607
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914186603665818
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897870349020118
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906979697764453
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902512739068398
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899904783686317
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9929881576638835
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904564971969045
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896000871930178
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899904116122493
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899384657326564
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989981513014218
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903412691966924
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989362313958966
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9920470920126517
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893623808354386
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902047579123403
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990147911712684
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9915714738602472
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905165289487399
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896417417575981
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9920622164463787
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907987104682674
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902661614223823
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914130379799353
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899145273552392
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901020195948215
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896414490955449
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901254005757226
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900935627717091
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989541429479357
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894827548375389
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911235008969612
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900785380274509
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913633244059222
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896199550752209
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896198521413868
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906506272810196
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899800437850849
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901753282957423
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896011371015333
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9917820280373433
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902242437563313
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902232939165303
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989378150771161
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.992068666680812
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899566459162163
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893764914367814
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903830337005439
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893625461982123
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900946133320196
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910909476435139
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9921478796620662
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904199954107717
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9909101459985468
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.991178676856146
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9909267397724173
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912168362767375
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9921044457968553
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893699021967535
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902003255623674
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912842952038684
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9916943099776437
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898203027675341
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990787002822345
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908204919473748
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903821311960999
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897798317286639
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901482205506427
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989362308396422
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990560072058148
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907669054015771
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893624814757769
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902903402114993
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903708369153145
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9909036451666356
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901652306177673
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901550258494513
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912639111507302
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899272262028558
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897791415552637
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9916950835091671
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895888112617909
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905076199827917
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908646289602854
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989362361220978
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912482315644692
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901891277961409
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901960849259132
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897871811440693
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906846806101869
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898468088253007
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896803241342872
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907533904768964
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9891071801995258
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907898637178729
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905701013255908
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990509054636327
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914441847798994
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910129432241963
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900936221198015
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907964263096717
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902835986652202
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9923012738820529
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901745234760284
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897169235188366
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895112237818469
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898975571331005
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900211133454084
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906694339954779
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902667811320433
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.99159524739221
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907938804814684
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898178831919662
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902994104941238
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899558252704385
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905883277535024
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894005043465384
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902192737781056
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903974895801589
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9909510378752313
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899808031436376
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913800296163731
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899800437851867
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898100497819543
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990053805723727
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903088480660608
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896756646087215
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896421626703509
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897729476580526
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9919599945110704
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896425479752442
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9919811637566774
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907370753033394
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902003813815005
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894924877032731
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899117317869603
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898035092499656
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910144764138673
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895311381104404
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911611896629295
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912694440524978
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.991310038593654
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910887169208773
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908211970927254
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.991081227767753
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893626631813268
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990087889195727
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898060476661665
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900809165190877
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912914889848872
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896000788594538
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911895920058431
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912437952565998
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894712191016445
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908409522303263
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897830229373655
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905834382479854
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893722358920307
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899221026354673
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904445170816969
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914884372004824
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893778286338175
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901758050014792
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898099666998631
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9909512799235881
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893627108049945
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9917907609288146
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893689618071826
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896866577981442
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903143874537728
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913937706768255
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902497478945731
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902723610247799
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908944085729358
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894014369710353
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900935476826992
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894931551543188
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989479237287547
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903930273850765
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895311442463881
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906140709609326
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903286262566483
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907389194895839
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905369880784304
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908545121803529
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900762386541331
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912556791065519
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990648163085392
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902360843093635
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904102736794512
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9915517970331416
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910170630167847
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894200081068121
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904523279883505
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910563200520203
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898397152466342
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901608563386808
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903483571009906
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904704532063197
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898114030313191
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901802034724178
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912168679007434
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896411656988164
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897803836054987
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896399696518483
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899499926763664
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893668254475038
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902260704094091
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989449379734353
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899766061008644
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912008124770907
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911228573837432
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905022439023586
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9917121238737616
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896545811280519
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990843368701078
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893690056801667
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906288300861854
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901749757846185
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898398904517831
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895400286087213
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898525926301396
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990490379059944
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990415662003969
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900039823663962
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905203396091539
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904611748964003
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901552069921576
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893872300693412
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903443451166828
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9917992508755469
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910911724551494
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904056591815205
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904769163930176
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896269772539867
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901995066875566
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906543346608039
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896224115296748
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914305131431337
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9909446758282634
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9916161132918787
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910336825284849
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989996421927715
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904979751157348
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899286295730043
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910095332958292
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898860575582143
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901751201083986
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902002254404183
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902002252693208
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906239353257501
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990357872705202
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902667627573281
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896997694248959
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900556594520358
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904389298340934
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908012740332608
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9915908250558276
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910716042999184
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903287874921103
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906039384914763
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903560458280138
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896998644753148
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907370462896622
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9919122357810746
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906373662163956
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9909612106262602
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903386300166159
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900908551353685
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901908742058936
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893865288887769
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905188581661546
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898540736629519
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896000713471802
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914877159202293
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904489697011863
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897160675454018
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905145231415973
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911611714460996
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897198884575916
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900136628948691
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911514988110148
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910319121198597
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910241858869888
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904008065660486
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908860092811125
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900314131110971
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904371436277484
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901452486797161
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907951799285502
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896711400213043
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904636156923421
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894783046628628
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904249384799186
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9909685974270024
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896132730801339
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898979143324302
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907764858931463
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903417731414512
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9882012269535461
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899658299261327
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895377453690497
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913766659337364
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905556463511884
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990535991848226
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904610762915442
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9917427573555979
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9918401294828469
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903348862831474
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913752697328487
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896242314450793
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913116627791766
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903541882468649
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906744452649672
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902132638302066
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896866199782304
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906179724216004
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910166261090976
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9917264480962429
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990488486919553
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895551430403313
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898114065952714
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905129029029498
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893624793217554
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902002413349741
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901608399298385
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901692876167403
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893623872363535
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895115061132967
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9922362580148268
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895697295458572
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9917636942447035
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912241848439369
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902601456124868
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901204796554468
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896796821183078
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912246086324437
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9918762500958939
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910542650761396
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893689616362722
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894786887163052
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9875718550006389
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905453070697282
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896003624918863
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896425740063621
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901502592049716
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989990411492395
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905829678110052
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897953652772797
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898202938312073
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906628543891323
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9915567356039972
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902145488998166
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911415073034379
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893623525603921
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989386392490426
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908598881647348
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903448043214591
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902563537313791
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913282673426398
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898448390675163
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9909477901557344
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914136491701919
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904649669260341
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893916870836235
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.99032854977477
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897095953848076
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905784342776829
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899211326642057
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911868470808025
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897497861218865
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907336124122741
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913144987380494
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895635520989201
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895452419869264
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989470931193162
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896710724303659
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902310547864897
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900975358822208
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898113011204408
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907179093211681
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903427326265878
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901014154530601
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9888670161073501
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897282926210957
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912299271435813
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906166419685886
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906493179056111
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905226286188467
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911979032775944
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898399571881316
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907142214541096
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906177063764444
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906780070051254
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912182195397131
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902257615864377
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913606871022181
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899903003485442
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900404170152145
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895505771789351
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895944718547387
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900250985952596
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990963519368006
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904550332889857
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901452695985743
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905977082193081
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899499948303547
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898511028899899
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899199483648483
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896456903569204
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912342375048215
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899144506692523
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9925387200702278
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990297268676132
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904499266566202
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903185096678115
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903635909853772
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914000332642778
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.991060334486734
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990283855460772
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897266965263477
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897675566328129
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903310887574872
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905234469832944
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910350596040818
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903165072904754
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899721943237036
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897160983186043
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901654941928192
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9909520969112119
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906627106879186
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989858354255374
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905408250096153
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893952244156304
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894775865868153
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894710100331698
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900245626039614
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905559197829895
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990843127338632
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893623590671764
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894005065003717
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9925243990978199
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912523771806464
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990313392372403
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990225748203361
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990303955894582
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904390114437773
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897856627749896
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905344953058288
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911282022772385
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898745340171489
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897079345439901
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900777200905502
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906491954613851
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895459905744508
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903690286440701
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908496287638464
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9916919048526397
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900759678241874
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906573812381494
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895461034878466
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907638797793428
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914256353854174
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990331944723007
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893782170531261
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902301928154305
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900976678607107
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906418536927912
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894530326512576
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.991500710082365
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989362342714186
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896001239679115
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9920240381311408
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908404065142333
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898010361023886
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904722541472131
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910207046137913
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897101755564423
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910189831436111
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904200245408294
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901278314076942
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913881854302897
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894792562328837
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.98975868675385
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903286317355904
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990532965480879
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904446434253932
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898179500684227
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896045214375931
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902903480988241
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899469780648605
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904788095115056
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904087983665131
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896338715323727
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989811335393525
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910245645233235
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897728441652778
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896336467146664
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9890233977157482
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906492234956822
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9918796464411984
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913771607457526
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908618792341707
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9916571367907937
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990294792539977
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901848099948339
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911411614978581
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896988649852839
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905971838032382
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893626403488158
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904012572070502
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904838050160387
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896998298544302
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900668901454931
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9917346214213134
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895548146957938
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903243389272045
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9915298614395234
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901056854099293
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900978415948912
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.993038294201565
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899358066054375
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900305138120153
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894007935249439
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899272422685458
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906907199635677
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9909683001026136
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897688238470198
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906754025503375
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.98996297990542
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899948272096548
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913680172851129
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899146225087188
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897871383219234
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907122342956245
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990363512627577
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989877947516054
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898352486273014
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906094329147535
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906001251582173
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895024021947983
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907000482172874
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898111965609013
# ...
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894784177370666
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904794430081071
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906481134879062
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902518723502605
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.991474116176486
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900975071267192
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9916705813618711
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897798394158953
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906305207108494
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911411838802786
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907170138703013
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9923302753894776
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898446071833429
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903351685886302
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989478475879044
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897572264684775
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900665473227065
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910936279581877
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896319538677936
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893624818152156
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906309875767754
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907981173440694
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903398587446786
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896381442021087
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9884783981600945
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893920432903733
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898660684667782
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.991375603989047
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895360484882144
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.992293854250456
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9918435056144753
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903540088394688
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900381711369307
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897772943526193
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894709655109782
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904695901216382
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893907770581423
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894200078869896
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911749861891276
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990502920454747
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989478304882524
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902003019555191
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901519582803755
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904334517314248
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893778468218366
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895658663674576
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.99073968207676
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907544030031626
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905644032851333
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893624793217642
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904538689185877
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.992146089905064
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9919933530927474
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9919811975503516
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.991992225080744
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896133460502712
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895890519241928
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9909366358892774
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990856037026697
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900055801536654
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904912980579973
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896712333793682
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897532879692571
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9915340717283352
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893625136553226
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896621102419176
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902003522396239
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9921121127696382
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911327031523598
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901914955908149
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901764401060896
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899824339989618
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899425267215135
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899234160237098
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901569223666018
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895178432004014
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989648564011711
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895441671747734
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900140689878675
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896711378675038
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895311053154465
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989785817275932
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897160674097517
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904390154203342
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896711952581175
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907017192348406
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913882996517868
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990340216884912
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893864347554215
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897160676136719
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905822227264676
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910362160811786
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902828198152493
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896711433259723
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900466967958634
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897101315126835
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895089729662703
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904010721181684
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906792075172826
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9916083167589822
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908770984105325
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893634500893946
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894784755884778
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906880139690105
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901465028271699
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.992444650277403
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9908254140665383
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904943936568975
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990838926986821
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905399597065494
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9916446333205271
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901891720594824
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903488827418964
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893932658937331
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898399573280445
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895413789794963
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905786419473241
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904511189711874
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911471086198649
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912821950352784
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989569307737073
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895452419869273
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894266611270255
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894776134078602
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906084126857014
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898298609976566
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914601338537026
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903778786211187
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903772659688066
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893624793220357
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904445458369253
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904906851030543
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895310632541188
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899070462284723
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903797047327004
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907425466930996
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9914886157866616
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899221791176361
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903418354711888
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898957751347526
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898165928395781
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906387718544956
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9909987839002836
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907308357137921
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901749471132104
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901285905425068
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893929769036547
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9893670884895333
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9917324001981562
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911668349357924
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895089729663222
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901935892144378
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990450341455084
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910336361586646
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902817468744283
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9896711377476435
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898112874468389
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905559489410793
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900230734658402
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902668444570165
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9894873922860687
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905466417218025
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9879459337042925
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904990266766605
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9922178897015541
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.990319128702879
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9906835066624695
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895943298044365
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9913575653709001
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9915112353706161
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902002274388404
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904790495851616
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895231699032312
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9912381374209922
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899519113085153
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9909813241899808
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9903969736394233
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9910971967873272
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911096065259172
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9897532844103696
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9902002921614953
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9898215813682959
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899859610349031
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9901191273018228
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.989362313958983
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9900461493455791
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9919963798145447
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9916263842061478
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9895312480756455
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9905167296611574
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9899941253834368
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9904635341426691
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9907280155292523

# %%
plt.plot(all_raster_kde['x'], estimated_medians)
plt.fill_between(all_raster_kde['x'], estimated_q5s, estimated_q95s, alpha =0.4)

plt.plot(all_raster_kde['x'], baseline_medians, color = 'black', lw = 1.5)
plt.fill_between(all_raster_kde['x'], baseline_q5s, baseline_q95s, color = 'lightgray', zorder = -100)

# %%
# export the median, quartiles, etc to file

bootstrap_kde = dict(
    x = all_raster_kde['x'], 
    baseline_median = baseline_medians,
    baseline_q5 = baseline_q5s, 
    baseline_q95 = baseline_q95s,
    estimated_median = estimated_medians, 
    estimated_q5 = estimated_q5s,
    estimated_q95 = estimated_q95s
)

bootstrap_kde = pd.DataFrame(bootstrap_kde)
bootstrap_kde.to_csv('../processed_data/kde_bootstrap.csv')

# %% [markdown]
# Export distance KDE

# %%
# make kdes for all
bandwidth = 0.01

# convert to numpy arrays
all_veloc = np.asarray(all_veloc)
dyad_veloc = np.asarray(dyad_veloc)
event_veloc = np.asarray(event_veloc)

# compute kde of velocities
kde_v_all = gt.utils.kde1d(all_veloc[~np.isnan(all_veloc)], bandwidth)
kde_v_interact = gt.utils.kde1d(dyad_veloc[~np.isnan(dyad_veloc)], bandwidth)
kde_v_events = gt.utils.kde1d(event_veloc[~np.isnan(event_veloc)], bandwidth)

kde_v_all = dict(x=kde_v_all[0], y = kde_v_all[1])
kde_v_interact = dict(x=kde_v_interact[0], y = kde_v_interact[1])
kde_v_events = dict(x=kde_v_events[0], y = kde_v_events[1])

kde_v_all = pd.DataFrame(kde_v_all)
kde_v_interact = pd.DataFrame(kde_v_interact)
kde_v_events = pd.DataFrame(kde_v_events)

kde_v_all.to_csv("../processed_data/kde_v_all.csv")
kde_v_interact.to_csv("../processed_data/kde_v_interact.csv")
kde_v_events.to_csv("../processed_data/kde_v_events.csv")
# Out:
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 1.0118666359165367
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9968494797949562
# computed AreaUnderCurve (AUC) of KDE using sklearn.metrics.auc: 0.9911281499297891
